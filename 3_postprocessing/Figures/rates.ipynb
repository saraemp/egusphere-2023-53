# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d

# %%
# Loading the files with the metrics e.g. flexure, accumulation
#Synthetic

Delta_SL0_Te50=pd.read_csv ('./extracted_results/Synthetic/Delta_SL0_Te50.csv',sep=',', header=0)
Delta_SL_f5Myr_A25m_Te50=pd.read_csv('./extracted_results//Synthetic/Delta_SL_f5Myr_A25m_Te50.csv', sep=',',header=0)
Delta_SL_f500Kyr_A25m_Te50=pd.read_csv ('./extracted_results//Synthetic/Delta_SL_f500Kyr_A25m_Te50.csv',sep=',', header=0)
Delta_SL0_NoFlex=pd.read_csv ('./extracted_results/Synthetic/Delta_SL0_Noflex.csv',sep=',', header=0)
Delta_SL_f5Myr_A25m_NoFlex=pd.read_csv('./extracted_results/Synthetic/Delta_SL_f5Myr_A25m_NoFlex.csv', sep=',',header=0)
Delta_SL_f500Kyr_A25m_NoFlex=pd.read_csv ('./extracted_results/Synthetic/Delta_SL_f500Kyr_A25m_NoFlex.csv',sep=',', header=0)

#IH GH
Delta_SL_IH_Te50=pd.read_csv ('./extracted_results/IH_GH/Miller/Delta_SL_IH_Te50.csv',sep=',', header=0)
# Delta_SL_IH_NoFlex=pd.read_csv ('/live/share/Delta_2020/Delta_data_extraction/IH_GH/Miller/Delta_SL_IH_NoFlex.csv',sep=',', header=0)
#Delta_SL_GH_Te50=pd.read_csv ('/extracted_results/IH_GH/Miller/Delta_SL_GH_Te50_120820manual.csv',sep=',', header=0)
# Delta_SL_GH_NoFlex=pd.read_csv ('/live/share/Delta_2020/Delta_data_extraction/IH_GH/Miller/Delta_SL_GH_NoFlex_120820manual.csv',sep=',', header=0)


# #Loading the sea level curves
# Delta_SL_f5Myr_A25m=pd.read_csv('/live/share/Delta_2020/Delta_running/data/f5Myr_A25m.csv', sep=' ',header=None)
# Delta_SL_f500Kyr_A25m=pd.read_csv('/live/share/Delta_2020/Delta_running/data/f500Kyr_A25m.csv', sep=' ',header=None)
# SL_IH=pd.read_csv('/live/share/Delta_2020/Delta_running/data/SL_IH.csv', sep=' ',header=None)
# SL_GH=pd.read_csv('/live/share/Delta_2020/Delta_running/data/SL_GH.csv', sep=' ',header=None)

# %%
Delta_SL_IH_Te50
# Out:
#                 X             Y          Z  River_mouth_Lengh_m    Flexure_m  \
# 0    0.000000e+00  0.000000e+00   0.000000         0.000000e+00     0.000000
# 1    2.086379e+06  1.006838e+06  -0.294096         2.269505e+06    -3.080594
# 2    2.088390e+06  1.016447e+06  -0.269158         2.279323e+06    -5.416471
# 3    2.117288e+06  9.888655e+05  -0.480072         2.306284e+06   -14.714185
# 4    2.082580e+06  9.953246e+05  -0.024623         2.269828e+06    -7.350628
# ..            ...           ...        ...                  ...          ...
# 115  2.640036e+06  9.646756e+05 -23.401764         3.340339e+06  -933.316615
# 116  2.707515e+06  9.785330e+05 -25.470780         3.467922e+06 -1060.141198
# 117  2.756967e+06  9.580312e+05 -30.371209         3.525352e+06 -1144.240553
# 118  1.987881e+06  9.860315e+05  18.077696         2.269309e+06   200.747666
# 119  2.242882e+06  1.078928e+06  25.487428         2.698242e+06  -217.206647
#
#      Accumulation_m  Accumulation_max_m  Flexure_min_m  Flexure_mean_m  \
# 0          0.000000            0.000000       0.000000        0.000000
# 1        -27.586696            9.438047     -12.002272       -2.596048
# 2        -44.506427           30.478981     -24.805032       -5.348685
# 3         -6.464756           45.273145     -37.572407      -11.167978
# 4         10.717874           60.576679     -49.944707       -9.252837
# ..              ...                 ...            ...             ...
# 115     1878.924671         2552.826703   -1212.269356     -916.751569
# 116     2160.956498         2575.667103   -1275.171180    -1025.566899
# 117     2347.708057         2589.767615   -1314.471415    -1099.413214
# 118     -321.604121         2619.967161    -112.389053      193.842896
# 119      462.581443         2661.684548    -583.449191     -213.845956
#
#      Flexure_max_m
# 0         0.000000
# 1         3.203049
# 2         7.303819
# 3        10.373192
# 4        15.314582
# ..             ...
# 115    -585.190146
# 116    -692.694894
# 117    -786.127829
# 118     359.639136
# 119     150.438292
#
# [120 rows x 10 columns]

# %%
nfile=len(Delta_SL0_Te50.X)
ts=np.arange(0,nfile,1)
realtime=(ts*10e6)/100
# plt.plot(Delta_SL_f500Kyr_A25m_Te50.Flexure_m-Delta_SL0_Te50.Flexure_m,realtime, 'green')
# plt.plot(Delta_SL_f5Myr_A25m_Te50.Flexure_m-Delta_SL0_Te50.Flexure_m,realtime, 'red')
x=Delta_SL0_Te50.Flexure_m
y3 = gaussian_filter1d(x, 3)
y6=gaussian_filter1d(x, 6)
# plt.plot(Delta_SL0_Te50.Flexure_m, realtime)
# plt.plot(y3, realtime)
plt.plot(y6, realtime)
plt.plot(gaussian_filter1d(Delta_SL_f5Myr_A25m_Te50.Flexure_m,4), realtime)
plt.plot(gaussian_filter1d(Delta_SL_f500Kyr_A25m_Te50.Flexure_m,1), realtime, 'green')
plt.plot(Delta_SL_f500Kyr_A25m_Te50.Flexure_m, realtime, 'darkgreen', linestyle='--')

# plt.plot(Delta_SL_f5Myr_A25m_Te50.Flexure_m, realtime)

# plt.plot(Delta_SL_f5Myr_A25m_Te50.Flexure_m, realtime)

# %%
#I need to get clarity on what this means, I was expecting the departures to be smaller, see below
#This is not refecting the hydro vs sediment load, this is reflecting how much the flexure changes because how the sediment is moved because of the sea-level changes
#The longprofiles would then show the topographic response to hydroisostasy 
#Need to clarify with Mike Blum what does he mean about bidirectional. 

plt.plot(gaussian_filter1d(Delta_SL_f5Myr_A25m_Te50.Flexure_m,4), realtime)

plt.plot(gaussian_filter1d(Delta_SL_f5Myr_A25m_Te50.Flexure_m,4)-
         gaussian_filter1d(Delta_SL0_Te50.Flexure_m, 6),realtime, 'red')
# plt.plot(Delta_SL_f500Kyr_A25m_Te50.Flexure_m-Delta_SL0_Te50.Flexure_m,realtime, 'green')

plt.plot(Delta_SL0_Te50.Flexure_m-Delta_SL0_Te50.Flexure_m,realtime, 'black')
plt.plot(Delta_SL0_Te50.Flexure_m, realtime)

# %%
plt.plot(np.gradient(gaussian_filter1d(Delta_SL_f5Myr_A25m_Te50.Flexure_m,4)), realtime, 'red')
plt.plot(np.gradient(gaussian_filter1d(Delta_SL_f500Kyr_A25m_Te50.Flexure_m,1)), realtime, 'green')
plt.plot(np.gradient(gaussian_filter1d(Delta_SL0_Te50.Flexure_m,1)), realtime, 'black')

# %%
nfile=len(Delta_SL0_Te50.X)
ts=np.arange(0,nfile-1,1)
realtime=(ts*10e6)/100

# %%
12e6/100000
# Out:
# 120.0

# %%
len(Delta_SL0_Te50.Flexure_m)
# Out:
# 120

# %%
plt.yscale("log")
plt.plot(abs(Delta_SL0_Te50.Flexure_m))
plt.plot(abs(np.gradient(Delta_SL0_Te50.Flexure_m)))

# %%
plt.plot(abs(np.gradient(Delta_SL0_Te50.Flexure_m)))

# %%
plt.plot(abs(np.gradient(Delta_SL_IH_Te50.Flexure_m)), color='blue')
plt.plot(abs(np.gradient(Delta_SL0_Te50.Flexure_m)))

# %%
# plt.plot(Delta_SL0_Te50.Flexure_m/1e5)
np.round((Delta_SL0_Te50.Flexure_m[119]*1e3)/12e6,3)
# Out:
# -0.11

# %%
time
# Out:
# array([       0.,   100000.,   200000.,   300000.,   400000.,   500000.,
#          600000.,   700000.,   800000.,   900000.,  1000000.,  1100000.,
#         1200000.,  1300000.,  1400000.,  1500000.,  1600000.,  1700000.,
#         1800000.,  1900000.,  2000000.,  2100000.,  2200000.,  2300000.,
#         2400000.,  2500000.,  2600000.,  2700000.,  2800000.,  2900000.,
#         3000000.,  3100000.,  3200000.,  3300000.,  3400000.,  3500000.,
#         3600000.,  3700000.,  3800000.,  3900000.,  4000000.,  4100000.,
#         4200000.,  4300000.,  4400000.,  4500000.,  4600000.,  4700000.,
#         4800000.,  4900000.,  5000000.,  5100000.,  5200000.,  5300000.,
#         5400000.,  5500000.,  5600000.,  5700000.,  5800000.,  5900000.,
#         6000000.,  6100000.,  6200000.,  6300000.,  6400000.,  6500000.,
#         6600000.,  6700000.,  6800000.,  6900000.,  7000000.,  7100000.,
#         7200000.,  7300000.,  7400000.,  7500000.,  7600000.,  7700000.,
#         7800000.,  7900000.,  8000000.,  8100000.,  8200000.,  8300000.,
#         8400000.,  8500000.,  8600000.,  8700000.,  8800000.,  8900000.,
#         9000000.,  9100000.,  9200000.,  9300000.,  9400000.,  9500000.,
#         9600000.,  9700000.,  9800000.,  9900000., 10000000., 10100000.,
#        10200000., 10300000., 10400000., 10500000., 10600000., 10700000.,
#        10800000., 10900000., 11000000., 11100000., 11200000., 11300000.,
#        11400000., 11500000., 11600000., 11700000., 11800000., 11900000.])

# %%
i=0
rates.append(np.round((Delta_SL0_Te50.Flexure_m[i]*1e3)/time[i],3))
rates
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# [-0.027, -0.111, -0.111, nan]

# %%
rates=[]
time=np.arange(1, 12e6, 1e5)

for i in np.arange(0, 120,1):
#     print(i, time[i])
    rates.append(np.round((Delta_SL0_Te50.Flexure_m[i]*1e3)/time[i],3))
rates
# Out:
# [0.0,
#  -0.031,
#  -0.027,
#  -0.049,
#  -0.018,
#  -0.009,
#  -0.007,
#  -0.005,
#  -0.01,
#  -0.009,
#  -0.007,
#  -0.012,
#  -0.015,
#  -0.013,
#  -0.012,
#  -0.011,
#  -0.022,
#  -0.021,
#  -0.019,
#  -0.022,
#  -0.021,
#  -0.02,
#  -0.026,
#  -0.024,
#  -0.023,
#  -0.028,
#  -0.026,
#  -0.03,
#  -0.029,
#  -0.028,
#  -0.032,
#  -0.031,
#  -0.03,
#  -0.037,
#  -0.036,
#  -0.035,
#  -0.039,
#  -0.038,
#  -0.042,
#  -0.041,
#  -0.04,
#  -0.039,
#  -0.047,
#  -0.046,
#  -0.048,
#  -0.047,
#  -0.05,
#  -0.048,
#  -0.051,
#  -0.05,
#  -0.053,
#  -0.052,
#  -0.054,
#  -0.053,
#  -0.06,
#  -0.061,
#  -0.06,
#  -0.066,
#  -0.065,
#  -0.064,
#  -0.062,
#  -0.068,
#  -0.069,
#  -0.072,
#  -0.073,
#  -0.072,
#  -0.071,
#  -0.074,
#  -0.075,
#  -0.075,
#  -0.078,
#  -0.083,
#  -0.081,
#  -0.082,
#  -0.082,
#  -0.082,
#  -0.084,
#  -0.085,
#  -0.084,
#  -0.085,
#  -0.087,
#  -0.083,
#  -0.085,
#  -0.086,
#  -0.087,
#  -0.088,
#  -0.087,
#  -0.093,
#  -0.095,
#  -0.094,
#  -0.095,
#  -0.097,
#  -0.096,
#  -0.097,
#  -0.096,
#  -0.097,
#  -0.098,
#  -0.1,
#  -0.1,
#  -0.099,
#  -0.101,
#  -0.102,
#  -0.101,
#  -0.1,
#  -0.103,
#  -0.104,
#  -0.105,
#  -0.106,
#  -0.105,
#  -0.104,
#  -0.105,
#  -0.104,
#  -0.105,
#  -0.109,
#  -0.108,
#  -0.106,
#  -0.11,
#  -0.109,
#  -0.109,
#  -0.111]

# %%
plt.plot(rates)

# %%
plt.plot(Delta_SL0_Te50.Flexure_m[0:-1], realtime/1e6, '-o')
